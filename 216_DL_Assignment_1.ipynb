# %% [markdown]
# #GRU

# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,GRU,Dense
from tensorflow.keras.preprocessing import sequence

# %%
max_words = 6000
(xt,yt),(xte,yte)= imdb.load_data(num_words=max_words)

max_len =500
xt=sequence.pad_sequences(xt,maxlen=max_len)
xte=sequence.pad_sequences(xte,maxlen=max_len)

model=Sequential()
model.add(Embedding(max_words,100,input_length=max_len))
model.add(GRU(128))
model.add(Dense(1,activation='sigmoid'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
batch_size=128
epochs=10
model.fit(xt,yt,batch_size=batch_size,epochs=epochs)
# Out:
# Epoch 1/10
# 196/196 [==============================] - 269s 1s/step - loss: 0.4916 - accuracy: 0.7479
# Epoch 2/10
# 196/196 [==============================] - 260s 1s/step - loss: 0.2772 - accuracy: 0.8876
# Epoch 3/10
# 196/196 [==============================] - 260s 1s/step - loss: 0.2197 - accuracy: 0.9146
# Epoch 4/10
# 196/196 [==============================] - 260s 1s/step - loss: 0.1783 - accuracy: 0.9333
# Epoch 5/10
# 196/196 [==============================] - 262s 1s/step - loss: 0.1370 - accuracy: 0.9496
# Epoch 6/10
# 196/196 [==============================] - 272s 1s/step - loss: 0.1091 - accuracy: 0.9604
# Epoch 7/10
# 196/196 [==============================] - 268s 1s/step - loss: 0.0964 - accuracy: 0.9661
# Epoch 8/10
# 196/196 [==============================] - 274s 1s/step - loss: 0.0664 - accuracy: 0.9788
# Epoch 9/10
# 196/196 [==============================] - 278s 1s/step - loss: 0.0481 - accuracy: 0.9850
# Epoch 10/10
# 196/196 [==============================] - 279s 1s/step - loss: 0.0329 - accuracy: 0.9903

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 85s 431ms/step - loss: 0.6616 - accuracy: 0.8655
# accuracy: 0.8655200004577637
# loss: 0.6615678668022156

# %%
history=model.fit(xt,yt,batch_size=batch_size,epochs=epochs)
# Out:
# Epoch 1/10
# 196/196 [==============================] - 279s 1s/step - loss: 0.0280 - accuracy: 0.9915
# Epoch 2/10
# 196/196 [==============================] - 279s 1s/step - loss: 0.0422 - accuracy: 0.9858
# Epoch 3/10
# 196/196 [==============================] - 279s 1s/step - loss: 0.0218 - accuracy: 0.9936
# Epoch 4/10
# 196/196 [==============================] - 278s 1s/step - loss: 0.0215 - accuracy: 0.9937
# Epoch 5/10
# 196/196 [==============================] - 278s 1s/step - loss: 0.0134 - accuracy: 0.9963
# Epoch 6/10
# 196/196 [==============================] - 278s 1s/step - loss: 0.0230 - accuracy: 0.9934
# Epoch 7/10
# 196/196 [==============================] - 277s 1s/step - loss: 0.0129 - accuracy: 0.9962
# Epoch 8/10
# 196/196 [==============================] - 281s 1s/step - loss: 0.0142 - accuracy: 0.9952
# Epoch 9/10
# 196/196 [==============================] - 278s 1s/step - loss: 0.0111 - accuracy: 0.9965
# Epoch 10/10
# 196/196 [==============================] - 280s 1s/step - loss: 0.0125 - accuracy: 0.9965

# %%
train_loss1 = history.history['loss']
train_acc1 = history.history['accuracy']
xc1=range(len(train_acc1))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc1, train_acc1)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %% [markdown]
# #LSTM

# %%
from tensorflow.keras.layers import Embedding,LSTM,Dense

# %%
model = Sequential()
model.add(Embedding(max_words,100, input_length=max_len))
model.add(LSTM(128))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
epochs = 5
batch_size = 128

hist=model.fit(xt, yt, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/5
# 196/196 [==============================] - 340s 2s/step - loss: 0.0998 - accuracy: 0.9646
# Epoch 2/5
# 196/196 [==============================] - 317s 2s/step - loss: 0.0592 - accuracy: 0.9806
# Epoch 3/5
# 196/196 [==============================] - 319s 2s/step - loss: 0.0571 - accuracy: 0.9813
# Epoch 4/5
# 196/196 [==============================] - 321s 2s/step - loss: 0.0880 - accuracy: 0.9688
# Epoch 5/5
# 196/196 [==============================] - 318s 2s/step - loss: 0.0456 - accuracy: 0.9866

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 115s 585ms/step - loss: 0.6084 - accuracy: 0.8494
# accuracy: 0.849399983882904
# loss: 0.6084098815917969

# %%
train_loss2 = hist.history['loss']
train_acc2 = hist.history['accuracy']
xc2=range(len(train_acc2))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc2, train_acc2)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %% [markdown]
# #RNN

# %%
from tensorflow.keras.layers import Embedding,RNN
from keras import layers

# %%
model = Sequential()
model.add(Embedding(max_words,100, input_length=max_len))
model.add(layers.LSTM(128))
model.add(layers.Dense(10))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
epochs = 7
batch_size = 128

h=model.fit(xt, yt, epochs=epochs, batch_size=batch_size, validation_split=0.2)
# Out:
# Epoch 1/7
# 157/157 [==============================] - 289s 2s/step - loss: 0.4741 - accuracy: 0.7628 - val_loss: 0.3343 - val_accuracy: 0.8664
# Epoch 2/7
# 157/157 [==============================] - 313s 2s/step - loss: 0.2660 - accuracy: 0.8963 - val_loss: 0.3049 - val_accuracy: 0.8728
# Epoch 3/7
# 157/157 [==============================] - 305s 2s/step - loss: 0.2101 - accuracy: 0.9194 - val_loss: 0.3317 - val_accuracy: 0.8734
# Epoch 4/7
# 157/157 [==============================] - 305s 2s/step - loss: 0.1635 - accuracy: 0.9404 - val_loss: 0.3560 - val_accuracy: 0.8460
# Epoch 5/7
# 157/157 [==============================] - 304s 2s/step - loss: 0.1805 - accuracy: 0.9292 - val_loss: 0.4051 - val_accuracy: 0.8450
# Epoch 6/7
# 157/157 [==============================] - 302s 2s/step - loss: 0.1095 - accuracy: 0.9613 - val_loss: 0.5541 - val_accuracy: 0.8558
# Epoch 7/7
# 157/157 [==============================] - 302s 2s/step - loss: 0.0813 - accuracy: 0.9722 - val_loss: 0.5268 - val_accuracy: 0.8500

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 114s 580ms/step - loss: 0.5314 - accuracy: 0.8456
# accuracy: 0.8456400036811829
# loss: 0.5314104557037354

# %%
train_loss3 = h.history['loss']
train_acc3 = h.history['accuracy']
xc3=range(len(train_loss3))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc3, train_acc3)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %%
plt.plot(xc1, train_acc1)
plt.plot(xc2, train_acc2)
plt.plot(xc3, train_acc3)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["GRU","LSTM","RNN"])
